# %%
# !python3 -m pip install pymongo
# !python3 -m pip install langchain langchain-openai
# Out:
# Requirement already satisfied: pymongo in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (4.16.0)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pymongo) (2.8.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: langchain in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (1.2.6)
# Requirement already satisfied: langchain-openai in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (1.1.7)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.7 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain) (1.2.7)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain) (1.0.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-openai) (2.15.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (0.6.4)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (0.14.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.6)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.1.15)
# Requirement already satisfied: requests>=2.26.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.32.5)
# Requirement already satisfied: idna>=2.8 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.109.1->langchain-openai) (3.11)
# Requirement already satisfied: certifi in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain-openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.7->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.10.1 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.6.3)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from pymongo import MongoClient

MONGO_URI = "mongodb+srv://mihir4:epicgames1@cluster0.vcik3qd.mongodb.net/risk-assessment?retryWrites=true&w=majority"

client = MongoClient(MONGO_URI)
db = client["risk-assessment"]
collection = db["userinputs"] 

latest_survey = collection.find_one(sort=[("_id", -1)])

print(latest_survey)
# Out:
# {'_id': ObjectId('696eb5060545982e603287d1'), 'risk_comfort': 6.6, 'growth_preference': 6.6, 'loss_tolerance': 6.6, 'time_horizon': 6, 'income_stability': 5, 'risk_category': 'Moderate', '__v': 0}

# %%
risk_comfort = latest_survey["risk_comfort"]
income_stability = latest_survey["income_stability"]
growth_preference = latest_survey["growth_preference"]
loss_tolerance = latest_survey["loss_tolerance"]
time_horizon = latest_survey["time_horizon"]
risk_category = latest_survey["risk_category"]

# %%
# !python3 -m pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (1.2.1)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
from pathlib import Path
load_dotenv()

PROJECT_ROOT = Path.cwd().parent


ENV_PATH = PROJECT_ROOT / "backEnd" / ".env"


load_dotenv(dotenv_path=ENV_PATH)


OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(f"Loaded API Key starts with: {OPENAI_API_KEY[:8]}")
# Out:
# Loaded API Key starts with: sk-proj-

# %%
from langchain_openai.chat_models import ChatOpenAI

model = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model="gpt-4.1")

# %%
# !python3 -m pip install pymupdf
# !python3 -m pip install --upgrade langchain
# Out:
# Requirement already satisfied: pymupdf in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (1.26.7)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: langchain in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (1.2.6)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.7 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain) (1.2.7)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain) (1.0.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (0.6.4)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (0.14.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.6)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.7->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (0.25.0)
# Requirement already satisfied: anyio in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.12.1)
# Requirement already satisfied: certifi in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (2.6.3)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import fitz

doc = fitz.open("riskassessmenttest.pdf") 
text = ""

for i, page in enumerate(doc):
    text += page.get_text()

# %%
# !pip install -U langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-text-splitters) (1.2.7)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.6.4)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: anyio in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (4.12.1)
# Requirement already satisfied: certifi in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2.6.3)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=20)
documents = text_splitter.split_text(text) 

documents
# Out:
# ['Investor Profile: Aggressive \n \nThis investment profile is designed for individuals who are comfortable with market volatility and \nare focused on maximizing long-term growth. You have demonstrated a strong tolerance for \nrisk, a preference for higher-growth opportunities, and the ability to stay invested through market \ndownturns. \n \nInvestment Strategy: \nAggressive investors should prioritize growth-oriented assets such as equities, growth stocks, \nsector-focused ETFs, and emerging market investments. A significant portion of the portfolio \ncan be allocated to higher-risk, higher-reward opportunities, as short-term fluctuations are less \nof a concern given your longer investment horizon. \n \nPortfolio Construction: \nA diversified equity-heavy portfolio is recommended, with exposure across multiple industries \nand geographies. Including a small allocation to alternative investments such as real estate',
#  'investment trusts (REITs) or innovation-focused funds can further enhance growth potential. \nWhile bonds may be included, they should play a minimal role primarily for liquidity and balance. \n \nRisk Management: \nEven with a high risk tolerance, diversification remains essential. Regularly reviewing and \nrebalancing your portfolio helps ensure that no single investment dominates your exposure. \nMaintaining an emergency fund outside of your investment portfolio allows you to avoid selling \nassets during market downturns. \n \nLong-Term Planning: \nAggressive investors benefit from a disciplined, long-term mindset. Staying invested, avoiding \nemotional decision-making, and continuing to invest consistently during both market highs and \nlows can significantly improve long-term outcomes. As your financial goals or income stability \nchange, reassessing your strategy is recommended. \n \n \nInvestor Profile: Moderate',
#  'This investment profile is suited for individuals seeking a balance between growth and stability. \nYou value steady progress toward your financial goals while remaining cautious about excessive \nrisk. Your preferences indicate a willingness to accept some volatility in exchange for higher \nlong-term returns. \n \nInvestment Strategy: \nModerate investors should focus on a balanced mix of equities and fixed-income assets. Broad \nmarket index funds, dividend-paying stocks, and high-quality bonds can work together to \nprovide growth while reducing downside risk. This approach allows participation in market gains \nwithout overexposure to volatility. \n \nPortfolio Construction: \nA well-diversified portfolio with a mix of domestic and international investments is \nrecommended. Equities should make up a meaningful portion of the portfolio, complemented by \nbonds or bond funds that provide stability and income. Periodic rebalancing helps maintain the \ndesired risk level over time.',
#  'Risk Management: \nRisk should be managed through diversification across asset classes and sectors. Avoid \nconcentrating investments in a single stock or industry. Maintaining liquidity for short-term needs \nensures that long-term investments can remain untouched during uncertain periods. \n \nLong-Term Planning: \nModerate investors benefit from consistent contributions and a long-term outlook. As your \nfinancial situation evolves, gradually adjusting your asset allocation can help align your portfolio \nwith changing goals. This strategy emphasizes sustainability, flexibility, and steady wealth \naccumulation. \n \nInvestor Profile: Conservative \n \nThis investment profile is intended for individuals who prioritize capital preservation and financial \nsecurity. You prefer minimizing losses and maintaining stability over pursuing high-risk growth \nopportunities. Your approach reflects caution and a focus on reliability. \n \nInvestment Strategy:',
#  'Conservative investors should emphasize lower-risk assets such as bonds, treasury securities, \nmoney market funds, and stable dividend-paying stocks. These investments aim to protect \nprincipal while generating modest, consistent returns. \n \nPortfolio Construction: \nA conservative portfolio should be heavily weighted toward fixed-income investments, with \nlimited exposure to equities. Diversification across high-quality bonds and stable asset classes \nhelps reduce volatility. Maintaining cash reserves provides flexibility and peace of mind. \n \nRisk Management: \nProtecting against losses is a primary goal. Avoid speculative investments and frequent trading. \nRegular portfolio reviews ensure that risk levels remain aligned with your comfort and financial \nneeds. \n \nLong-Term Planning: \nConservative investors should focus on maintaining purchasing power and financial stability \nover time. While returns may be lower, this approach reduces uncertainty and supports',
#  'long-term financial confidence. As circumstances change, incremental adjustments can help \nmaintain balance without introducing excessive risk.']

# %%
# !pip install -U langchain-pinecone langchain-openai
# Out:
# Requirement already satisfied: langchain-pinecone in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (0.2.13)
# Requirement already satisfied: langchain-openai in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (1.1.7)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.34 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-pinecone) (1.2.7)
# Requirement already satisfied: pinecone<8.0.0,>=6.0.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (7.3.0)
# Requirement already satisfied: numpy!=2.0.2,>=1.26.4 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-pinecone) (2.3.1)
# Requirement already satisfied: httpx>=0.28.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-pinecone) (0.28.1)
# Requirement already satisfied: simsimd>=5.9.11 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-pinecone) (6.5.12)
# Requirement already satisfied: pydantic>=2.11.1 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-pinecone) (2.12.5)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-openai) (2.15.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: anyio in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx>=0.28.0->langchain-pinecone) (4.12.1)
# Requirement already satisfied: certifi in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx>=0.28.0->langchain-pinecone) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx>=0.28.0->langchain-pinecone) (1.0.9)
# Requirement already satisfied: idna in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx>=0.28.0->langchain-pinecone) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.28.0->langchain-pinecone) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (0.6.4)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.8.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.0.post0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.6.3)
# Requirement already satisfied: aiohttp>=3.9.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (3.13.3)
# Requirement already satisfied: aiohttp-retry<3.0.0,>=2.9.1 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic>=2.11.1->langchain-pinecone) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic>=2.11.1->langchain-pinecone) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic>=2.11.1->langchain-pinecone) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.1.15)
# Requirement already satisfied: requests>=2.26.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.32.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.22.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (0.25.0)
# Requirement already satisfied: six>=1.5 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from python-dateutil>=2.5.3->pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mihirkulkarni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.4)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from langchain_pinecone import PineconeVectorStore

from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

index_name = "rag-first"

pinecone = PineconeVectorStore.from_texts(
    documents, embeddings, index_name=index_name
)

# %%
from langchain_core.runnables import RunnableParallel, RunnablePassthrough
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser



parser = StrOutputParser()

template = """
You are a personalized financial assistant.

You are advising a user with the following investment profile:

Risk Profile Summary:
- Risk Comfort: {risk_comfort}
- Growth Preference: {growth_preference}
- Loss Tolerance: {loss_tolerance}
- Time Horizon: {time_horizon}
- Income Stability: {income_stability}
- Risk Category: {risk_category}

Use this profile to tailor your advice.

Context (retrieved knowledge):
{context}

User Question:
{question}

Answer in a way that matches the user's risk profile.
"""

prompt = ChatPromptTemplate.from_template(template)
chain = (
    RunnableParallel(
        context=pinecone.as_retriever(),
        question=RunnablePassthrough(),

        risk_comfort=lambda _: latest_survey["risk_comfort"],
        growth_preference=lambda _: latest_survey["growth_preference"],
        loss_tolerance=lambda _: latest_survey["loss_tolerance"],
        time_horizon=lambda _: latest_survey["time_horizon"],
        income_stability=lambda _: latest_survey["income_stability"],
        risk_category=lambda _: latest_survey["risk_category"],
    )
    | prompt
    | model
    | parser
)

def retrieval_question(user_question):
    return (
        f"Investor Profile: {latest_survey['risk_category']}. "
        f"{user_question}"
    )

response = chain.invoke(retrieval_question("Give advice on risk assessment based on my profile"))
print(response)
# Out:
# Given your **moderate risk profile**—with above-average comfort with risk, growth preference, and loss tolerance (all at 6.6), a solid time horizon (6), and moderate income stability (5)—here’s personalized advice on **risk assessment**:
#
# ---
#
# ### 1. **Understand Your Risk Tolerance**
# - You are comfortable with some fluctuations in your portfolio in exchange for higher long-term returns, but you aren’t seeking aggressive, high-risk bets.
# - You can withstand moderate market downturns without rushing to sell investments, though you value a degree of stability.
#
# ### 2. **Prioritize Diversification**
# - **Diversify across asset classes:** Don’t concentrate in a single stock or sector; spread your investments among equities, high-quality bonds, and perhaps some alternative assets (like REITs or commodities) to smooth out volatility.
# - **Global diversification:** Include both domestic and international exposure for further risk reduction.
#
# ### 3. **Balance Growth and Stability**
# - Aim for a **balanced portfolio**—typically around **60% equities and 40% fixed income** is common for moderate-risk investors, though this can be adjusted slightly based on personal circumstances and market outlook.
# - Within equities, consider a mix: broad-market index funds, some dividend-paying stocks, and perhaps a small allocation to more defensive sectors.
#
# ### 4. **Liquidity Matters**
# - Maintain enough liquid assets (like cash or money market funds) to cover short-term needs and unexpected expenses, so you don’t have to sell long-term investments in a downturn.
#
# ### 5. **Monitor and Adjust**
# - **Review your portfolio regularly** (at least annually) to ensure it still aligns with your risk tolerance and life situation.
# - **Rebalance as needed:** This means adjusting your holdings if market movements have shifted your allocation away from your target balance.
#
# ### 6. **Stay the Course**
# - With a moderate approach, **focus on the long term** and resist the urge to make drastic changes during temporary market declines. Gradual, consistent contributions over time can help smooth out the impacts of volatility.
#
# ---
#
# **Summary:**
# Your risk assessment should reflect your willingness and capacity to withstand moderate ups and downs in pursuit of growth, balanced by enough stability so you can invest confidently for the future. Diversification, regular review, and a steady, balanced allocation are key to managing risk at your comfort level.
