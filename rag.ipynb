# %%
import os
from dotenv import load_dotenv

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(f"Loaded API Key starts with: {OPENAI_API_KEY[:8]}")
# Out:
# Loaded API Key starts with: sk-proj-

# %%
from langchain_openai.chat_models import ChatOpenAI

model = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model="gpt-4.1-mini")

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()
# Out:
# 'The MLB team that won the World Series during the COVID-19 pandemic in 2020 was the Los Angeles Dodgers. They defeated the Tampa Bay Rays to claim the championship.'

# %%
import fitz

doc = fitz.open("David Ahn_Cover Letter_Federal Board Reserve.pdf") 
text = ""

for i, page in enumerate(doc):
    text += page.get_text()

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=20)
documents = text_splitter.split_text(text) 

documents
# Out:
# ["David Ahn  \nCollege Park, MD, 20742, \ndavidahn1108@gmail.com | (213) 447-5377  \nDear Hiring Committee, \nI am writing to express my strong interest in the 2026 Summer Internship Program at the Federal \nReserve Bank of Richmond. As a Computer Science major at the University of Maryland with a \nconcentration in machine learning, I bring a strong technical foundation, extensive research \nexperience, and genuine passion for applying data and technology to serve the public good. I am \nespecially drawn to the Federal Reserve's mission to strengthen and protect the economy, and I \nwould be honored to contribute to that purpose. \n \nThrough the First-Year Innovation and Research Experience (FIRE) program at UMD, I am \ncurrently developing a machine learning model that predicts stock market behavior using \nsentiment analysis from employee reviews and financial news, which is work that involves \ngathering, cleaning, and analyzing large datasets to produce meaningful insights. My earlier",
#  'research through the Pioneer Academics Program focused on applying homomorphic encryption \nto neural networks, and I authored a comparative study of ML models for stock forecasting the \nJournal of Emerging Investigators. \nIn addition to research, I’ve worked in client-oriented settings, most notably as an intern with \nCanyon View Technology, where I redesigned the UI of an autonomous vehicle control system \nfor a U.S. Air Force client. This required me to not only write efficient, maintainable code but \nalso communicate recommendations across teams and incorporate user feedback into real-time \ndesign improvements, which are skills directly relevant to cross-functional collaboration and \nstakeholder engagement at the Richmond Fed. \nI am proficient in Python, Java, C, C++, and HTML, and have experience with tools such as \nPandas, NumPy, Matplotlib, and Excel for analytics and visualization. My technical background',
#  'is complemented by a strong interest in business analysis, public policy, and systems thinking—\nmaking this internship a perfect opportunity to bridge my technical skills with meaningful \nsocietal impact. \nWhat excites me most about this opportunity is the chance to learn from and contribute to an \ninstitution at the intersection of technology, finance, and public service. I am eager to gain \nhands-on experience in process improvement, stakeholder communication, and data-driven \ndecision-making while working on real-world challenges that support the broader economy. \nThank you for considering my application. I would be honored to have the opportunity to \ncontribute to the Fed’s mission and learn from its outstanding team next summer. I look forward \nto the possibility of discussing my background in more detail. \nSincerely, \nDavid Ahn']

# %%
from langchain_pinecone import PineconeVectorStore
from langchain_openai.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

index_name = "risk-assessment"

pinecone = PineconeVectorStore.from_texts(
    documents, embeddings, index_name=index_name
)

# %%
from pymongo import MongoClient
from typing import Optional

MONGODB_URI = os.getenv("MONGODB_URI")  
DB_NAME = os.getenv("MONGODB_DB")     
COLLECTION_NAME = os.getenv("MONGODB_COLLECTION")  

client = MongoClient(MONGODB_URI)
db = client[DB_NAME]
users_collection = db[COLLECTION_NAME]

def get_investing_type(email: str) -> Optional[str]:
    user = users_collection.find_one({"email": email}, {"risk_category": 1, "_id": 0})
    if user:
        return user["risk_category"]
    return None
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 9
#       6 COLLECTION_NAME = os.getenv("MONGODB_COLLECTION")
#       8 client = MongoClient(MONGODB_URI)
# ----> 9 db = client[DB_NAME]
#      10 users_collection = db[COLLECTION_NAME]
#      12 def get_investing_type(user_id: str) -> Optional[str]:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymongo/synchronous/mongo_client.py:1347, in MongoClient.__getitem__(self, name)
#    1339 def __getitem__(self, name: str) -> database.Database[_DocumentType]:
#    1340     """Get a database by name.
#    1341
#    1342     Raises :class:`~pymongo.errors.InvalidName` if an invalid
#    (...)
#    1345     :param name: the name of the database to get
#    1346     """
# -> 1347     return database.Database(self, name)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymongo/synchronous/database.py:125, in Database.__init__(self, client, name, codec_options, read_preference, write_concern, read_concern)
#     122 from pymongo.synchronous.mongo_client import MongoClient
#     124 if not isinstance(name, str):
# --> 125     raise TypeError(f"name must be an instance of str, not {type(name)}")
#     127 if not isinstance(client, MongoClient):
#     128     # This is for compatibility with mocked and subclassed types, such as in Motor.
#     129     if not any(cls.__name__ == "MongoClient" for cls in type(client).__mro__):
#
# TypeError: name must be an instance of str, not <class 'NoneType'>

# %%
from langchain_core.runnables import RunnableParallel, RunnablePassthrough
from langchain.prompts import ChatPromptTemplate

template = """
Answer the question based on the context below. If you can't 
answer the question, reply "I don't know". Keep in mind that the user's investing type is {investType}

Context: {context}

Question: {question}

"""

prompt = ChatPromptTemplate.from_template(template)
chain = (
    {"context": pinecone.as_retriever(), "question": RunnablePassthrough(), "investType": RunnablePassthrough()}
    | prompt
    | model
    | parser
)

user_id = "placeholder" #this should be retrived from the login session, either from frontend or the authorization apge
question = "What investment strategy should I follow?"

investing_type = get_investing_type(user_id)

if investing_type is None:
    response = "I don't know"
else:
    response = chain.invoke({
        "question": question,
        "investType": investing_type
    })

print(response)
# Out:
# "I don't know"
